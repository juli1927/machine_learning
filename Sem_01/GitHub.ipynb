# %%
# %cd /content/drive/MyDrive/Machine learning
# Out:
# /content/drive/MyDrive/Machine learning

# %%
# !git clone https://github.com/juli1927/machine_learning.git
# Out:
# Cloning into 'machine_learning'...
# remote: Enumerating objects: 137, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 137 (delta 39), reused 44 (delta 25), pack-reused 73
# Receiving objects: 100% (137/137), 144.09 KiB | 3.89 MiB/s, done.
# Resolving deltas: 100% (53/53), done.

# %%
# %cd /content/drive/MyDrive/Machine learning/machine_learning/
# !ls
# Out:
# /content/drive/MyDrive/Machine learning/machine_learning
# Images	   Sem_01  Sem_03  Sem_05  Sem_07  Sem_09  Sem_11
# README.md  Sem_02  Sem_04  Sem_06  Sem_08  Sem_10

# %%
# !git config --global user.email "julitomyduque@gmail.com"
# !git config --global user.name "juli1927"

# %%
# !git add Sem_01/GitHub.ipynb
# !git commit -m "Agrega GitHub.ipynb"
# Out:
# [master 2d4e426] Agrega GitHub.ipynb
#  1 file changed, 1 insertion(+)
#  create mode 100644 Sem_01/GitHub.ipynb

# %%
# !ls
# Out:
# Images	   Sem_01  Sem_03  Sem_05  Sem_07  Sem_09  Sem_11
# README.md  Sem_02  Sem_04  Sem_06  Sem_08  Sem_10

# %%
from Sem_01.repo_private import GIT_KEY
git_token = GIT_KEY
username = "juli1927"
repository = "machine_learning"
# Out:
# /content/drive/MyDrive/Machine learning/machine_learning/Sem_01

# %%
print(git_token)
# Out:
# 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

# %%
# !git remote set-url origin https://{git_token}@github.com/{username}/{repository}.git

# %%
# !echo "Contenido del archivo" > example.txt

# %%
# !git add example.txt

# %%
# !git commit -m "Agregando el archivo example.txt"
# Out:
# [master 8171680] Agregando el archivo example.txt
#  1 file changed, 1 insertion(+)
#  create mode 100644 example.txt

# %%
# !git push -u origin master
# Out:
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (7/7), 1.80 KiB | 102.00 KiB/s, done.
# Total 7 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 2 local objects.
# To https://github.com/juli1927/machine_learning.git
#    b824358..8171680  master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
# Add the remote, call it "upstream":
# !git remote add upstream https://github.com/rubenfonnegra/machine_learning.git

# %%
# !git checkout master  # Cambia a tu rama local
# !git merge upstream/master  # Fusiona los cambios desde upstream/master a tu rama local
# Out:
# M	Sem_01/GitHub.ipynb
# M	Sem_01/repo_keys_sample.txt
# M	Sem_01/repo_private.py
# Already on 'master'
# Your branch is up to date with 'origin/master'.
# Already up to date.

# %%
# !git push origin master
# Out:
# Everything up-to-date

# %%
# !git fetch upstream

# %%
# !git checkout master

# Rewrite your master branch so that any commits of yours that
# aren't already in upstream/master are replayed on top of that
# other branch:
# !git rebase upstream/master
# Out:
# M	Sem_01/GitHub.ipynb
# M	Sem_01/repo_keys_sample.txt
# M	Sem_01/repo_private.py
# Already on 'master'
# Your branch is up to date with 'origin/master'.
# error: cannot rebase: You have unstaged changes.
# error: Please commit or stash them.
